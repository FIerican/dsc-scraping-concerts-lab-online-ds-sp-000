# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Create a full scraping pipeline that involves traversing over many pages of a website, dealing with errors and storing data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
# Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
# Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

html_page = requests.get('https://www.residentadvisor.net/events')
soup = BeautifulSoup(html_page.content, 'html.parser')
soup.prettify
events = soup.findAll('article', class_="event-item")
events
# Out:
# [<article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-07-25T00:00" itemprop="startDate">2020-07-25T00:00</time></span><a href="/events/1399703"><img height="76" src="/images/events/flyer/2020/7/us-0725-1399703-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1399703" itemprop="url" title="Event details of FNGRS CRSSD Pres: OTR">FNGRS CRSSD Pres: OTR</a> <span>at <a href="/club.aspx?id=79291">Bang Bang</a>, <a href="/events.aspx?ai=309">San Diego</a></span></h1><div class="grey event-lineup">OTR</div><p class="attending"><span>2</span> Attending</p></div></article>,
#  <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event"><a href="/events/1361257#tickets"><img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/></a><span style="display:none;"><time datetime="2020-07-25T00:00" itemprop="startDate">2020-07-25T00:00</time></span><a href="/events/1361257"><img height="76" src="/images/events/flyer/2020/7/us-0724-1361257-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1361257" itemprop="url" title="Event details of [POSTPONED] Sunset Campout 2020">[POSTPONED] Sunset Campout 2020</a> <span>at <a href="/club.aspx?id=30680">Belden Town</a>, <a href="/events.aspx?ai=218">San Francisco</a></span></h1><div class="grey event-lineup">Galen, Solar, J-Bird, Special Guests</div><p class="attending"><span>288</span> Attending</p></div></article>,
#  <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-07-26T00:00" itemprop="startDate">2020-07-26T00:00</time></span><a href="/events/1418570"><img height="76" src="/images/events/flyer/2020/7/us-0726-1418570-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1418570" itemprop="url" title="Event details of Set presents 'Mask.Erade' Sunday">Set presents 'Mask.Erade' Sunday</a> <span>at <a href="/club.aspx?id=104750">The Midway</a>, <a href="/events.aspx?ai=218">San Francisco</a></span></h1><div class="grey event-lineup">Fathom D, The Rev. Hooman, Leyl Master Black, Proper Brother, Shri, Verlk</div><p class="attending"><span>1</span> Attending</p></div></article>,
#  <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event"><a href="/events/1361257#tickets"><img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/></a><span style="display:none;"><time datetime="2020-07-26T00:00" itemprop="startDate">2020-07-26T00:00</time></span><a href="/events/1361257"><img height="76" src="/images/events/flyer/2020/7/us-0724-1361257-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1361257" itemprop="url" title="Event details of [POSTPONED] Sunset Campout 2020">[POSTPONED] Sunset Campout 2020</a> <span>at <a href="/club.aspx?id=30680">Belden Town</a>, <a href="/events.aspx?ai=218">San Francisco</a></span></h1><div class="grey event-lineup">Galen, Solar, J-Bird, Special Guests</div><p class="attending"><span>288</span> Attending</p></div></article>,
#  <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-07-30T00:00" itemprop="startDate">2020-07-30T00:00</time></span><a href="/events/1404674"><img height="76" src="/images/events/flyer/2020/4/us-0409-1404674-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1404674" itemprop="url" title="Event details of Sequence Feat. Gentlemen's Club &amp; Dirty Snatcha">Sequence Feat. Gentlemen's Club &amp; Dirty Snatcha</a> <span>at <a href="/club.aspx?id=4164">DNA Lounge</a>, <a href="/events.aspx?ai=218">San Francisco</a></span></h1><div class="grey event-lineup">Gentlemen's Club, Dirty Snatcha</div><p class="attending"><span>1</span> Attending</p></div></article>,
#  <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-07-31T00:00" itemprop="startDate">2020-07-31T00:00</time></span><a href="/events/1390717"><img height="76" src="/images/listing-default.gif" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1390717" itemprop="url" title="Event details of Squish 1 Year Anniversary">Squish 1 Year Anniversary</a> <span>at <a href="/club.aspx?id=35088">Public Works</a>, <a href="/events.aspx?ai=218">San Francisco</a></span></h1><div class="grey event-lineup">TBA</div><p class="attending"><span>9</span> Attending</p></div></article>,
#  <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2020-07-31T00:00" itemprop="startDate">2020-07-31T00:00</time></span><a href="/events/1419234"><img height="76" src="/images/events/flyer/2020/7/us-0731-1419234-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1419234" itemprop="url" title="Event details of Factory 93 presents Eli &amp; Fur, Sacha Robotti, Shiba San, and Umek Livestream">Factory 93 presents Eli &amp; Fur, Sacha Robotti, Shiba San, and Umek Livestream</a> <span>at <span class="grey" style="display:inline;">Livestream</span></span></h1><div class="grey event-lineup">Eli &amp; Fur, Sacha Robotti, Shiba San, Umek</div><p class="attending"><span>2</span> Attending</p></div></article>]

# %%
events[0].find('h1', class_="event-title").text.split(' at ')[0].strip()
# Out:
# 'Void 001'

# %%
# venue
events[6].findAll('span')[-2].text.strip('at ')
# Out:
# 'Livestream'

# %%
# event date
events[1].find('time').text
# Out:
# '2020-07-25T00:00'

# %%
# number of attendees
events[1].find('p', class_="attending").find('span').text
# Out:
# '288'

# %%
def scrape_events(events_page_url): 

    html_page = requests.get(events_page_url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    events = soup.findAll('article', class_="event-item")
    
    Event_Name = []
    Venue = []
    Event_Date = []
    Number_of_Attendees = []
    i = 0
    
    while i < len(events):

        Event_Name.append(events[i].find('h1', class_="event-title").text.split(' at ')[0].strip())
            
        Venue.append(events[i].findAll('span')[-2].text.strip('at '))

        Event_Date.append(events[i].find('time').text)
    
        try:
            Number_of_Attendees.append(events[i].find('p', class_="attending").find('span').text)
        except Exception:
            0
        i += 1
        
    df = pd.DataFrame([Event_Name, Venue, Event_Date, Number_of_Attendees]).transpose()
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    return df

# %%
scrape_events('https://www.residentadvisor.net/events')
# Out:
#                                           Event_Name  \
# 0                              FNGRS CRSSD Pres: OTR
# 1                    [POSTPONED] Sunset Campout 2020
# 2                   Set presents 'Mask.Erade' Sunday
# 3                    [POSTPONED] Sunset Campout 2020
# 4    Sequence Feat. Gentlemen's Club & Dirty Snatcha
# 5                          Squish 1 Year Anniversary
# 6  Factory 93 presents Eli & Fur, Sacha Robotti, ...
#
#                          Venue        Event_Date Number_of_Attendees
# 0         Bang Bang, San Diego  2020-07-25T00:00                   2
# 1   Belden Town, San Francisco  2020-07-25T00:00                 288
# 2    The Midway, San Francisco  2020-07-26T00:00                   1
# 3   Belden Town, San Francisco  2020-07-26T00:00                 288
# 4    DNA Lounge, San Francisco  2020-07-30T00:00                   1
# 5  Public Works, San Francisco  2020-07-31T00:00                   9
# 6                   Livestream  2020-07-31T00:00                   2

# %%
soup.find('a', attrs={'ga-event-action':"Next "}).attrs['href']
# Out:
# '/events/us/california/week/2020-08-01'

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
# def next_page(url):
    
#     html_page = requests.get(url)
#     soup = BeautifulSoup(html_page.content, 'html.parser')
    
#     ext = soup.find('a', attrs={'ga-event-action':"Next "}).attrs['href']
#     next_page_url = "https://www.residentadvisor.net" + ext
#     return next_page_url

def next_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    url_ext = soup.find('a', attrs={'ga-event-action':"Next "}).attrs['href']
    next_page_url = "https://www.residentadvisor.net" + url_ext
    #Your code here
    return next_page_url

# %% [markdown]
# ## Scrape the Next 40 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
#Your code here
import time

events_url = 'https://www.residentadvisor.net/events/'
requested_events = []
total_rows = 0

while total_rows < 40:
    df = scrape_events(events_url)
    requested_events.append(df)
    total_rows += len(df)
    events_url = next_page(events_url)
    time.sleep(.2)
    
df = pd.concat(requested_events)
print(len(df))
df
# Out:
# 42
#                                           Event_Name  \
# 0                              FNGRS CRSSD Pres: OTR
# 1                    [POSTPONED] Sunset Campout 2020
# 2                   Set presents 'Mask.Erade' Sunday
# 3                    [POSTPONED] Sunset Campout 2020
# 4    Sequence Feat. Gentlemen's Club & Dirty Snatcha
# 5                          Squish 1 Year Anniversary
# 6  Factory 93 presents Eli & Fur, Sacha Robotti, ...
# 0                 Sequence Feat. Tisoki & Minesweepa
# 0                  Sequence feat. Spag Heddy & Effin
# 0                               Sequence Feat. Arius
# 0  [RESCHEDULED] Noche Dé Techno & Chaka Movement...
# 0                                           Void 001
# 1                                        John Legend
# 0                                     The Young Gods
# 1                         Sequence Feat. Delta Heavy
# 0                                Keinemusik Showcase
# 1                                      Influence-Con
# 2                                5 Seconds of Summer
# 3  [RESCHEDULED] Robot Ears: Luigi Tozzi (Hypnus,...
# 0                                          CamelPhat
# 1            [RESCHEDULED] Monolink with Viken Arman
# 2                      Analog+Wax Label Launch Party
# 3             Be Svendsen 'Man On The Run' Tour 2020
# 0                      [RESCHEDULED] Atish All Night
# 1  [RESCHEDULED] DEEP-LA x Be Svendsen with 'Man ...
# 2                      Analog+Wax Label Launch Party
# 3  [POSTPONED] DJ Tennis and Gerd Janson Block Pa...
# 4  [POSTPONED] Satori, Geju & Niki Sadeki: presen...
# 5                  [Postponed ] Kruder & Dorfmeister
# 0                                      Four Tet Live
# 0            Midnight Lovers with Cinthie (LA Debut)
# 1                   [RESCHEDULED] Bedouin & Einmusik
# 0        Cancelled - Mardeleva Live in San Francisco
# 1             Mardeleva Live in San Francisco - Pawa
# 2  [RESCHEDULED] Cassy [Special Open to Close set...
# 0  Midnight Lovers with Detroit Swindle (Extended...
# 0                                       Squarepusher
# 0                      Andreas Henneberg & Beth Lydi
# 0                                            US test
# 0                 Paradise in the Park (Rescheduled)
# 1                 Paradise in the Park (Rescheduled)
# 2            West Coast Weekender 5 Year Anniversary
#
#                                       Venue        Event_Date  \
# 0                      Bang Bang, San Diego  2020-07-25T00:00
